# %% [markdown]
# # Missing Values

# %%
import pandas as pd
import missingno as msno

# %%
df = pd.read_csv("datasets/Telco-Customer-Churn.csv")

# %%
msno.bar(df)
# Out:
# <AxesSubplot: >

# %%
msno.matrix(df)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Determining Missing Values

# %%
df.describe().T
# Out:
#                  count       mean        std    min   25%    50%    75%     max
# SeniorCitizen   7043.0   0.162147   0.368612   0.00   0.0   0.00   0.00    1.00
# tenure          7043.0  32.371149  24.559481   0.00   9.0  29.00  55.00   72.00
# MonthlyCharges  7043.0  64.761692  30.090047  18.25  35.5  70.35  89.85  118.75

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0  7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1  5575-GNVDE    Male              0  ...          56.95       1889.5     No
# 2  3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 3  7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 4  9237-HQITU  Female              0  ...          70.70       151.65    Yes
#
# [5 rows x 21 columns]

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# Understand to TotalCharges column values are float type but have to convert it to numeric.

# %%
df.TotalCharges = pd.to_numeric(df.TotalCharges, errors='coerce')

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
from feature_utils import get_null_summary

# %%
get_null_summary(df, 1)
# Out:
# 2023-03-27 06:31:11,521 - logging_utils - DEBUG - get_null_summary executing...
# 2023-03-27 06:31:11,538 - logging_utils - INFO -
#                   null  not-null
# customerID           0      7043
# gender               0      7043
# SeniorCitizen        0      7043
# Partner              0      7043
# Dependents           0      7043
# tenure               0      7043
# PhoneService         0      7043
# MultipleLines        0      7043
# InternetService      0      7043
# OnlineSecurity       0      7043
# OnlineBackup         0      7043
# DeviceProtection     0      7043
# TechSupport          0      7043
# StreamingTV          0      7043
# StreamingMovies      0      7043
# Contract             0      7043
# PaperlessBilling     0      7043
# PaymentMethod        0      7043
# MonthlyCharges       0      7043
# TotalCharges        11      7032
# Churn                0      7043

# %%
df.dropna(inplace=True)

# %%
df.to_csv('datasets/telco-nonmissing.csv', index=False)

# %% [markdown]
# Continue with **outliers jupyter file**.

# %%
import pandas as pd

# Read CSV file from URL
url = "https://raw.githubusercontent.com/treselle-systems/customer_churn_analysis/master/WA_Fn-UseC_-Telco-Customer-Churn.csv"
df = pd.read_csv(url)

# Check for missing values
print(df.isna().sum())
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

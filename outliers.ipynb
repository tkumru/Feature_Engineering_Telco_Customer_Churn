# %% [markdown]
# # Outliers

# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/telco-nonmissing.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0  7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1  5575-GNVDE    Male              0  ...          56.95      1889.50     No
# 2  3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 3  7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 4  9237-HQITU  Female              0  ...          70.70       151.65    Yes
#
# [5 rows x 21 columns]

# %%
from feature_utils import get_columns_type

# %%
numeric_cols, categoric_cols, cardinal_cols = get_columns_type(df)
# Out:
# 2023-03-27 06:36:06,686 - logging_utils - DEBUG - get_columns_type executing...
# 2023-03-27 06:36:06,696 - logging_utils - INFO -
# Numeric Columns: ['tenure', 'MonthlyCharges', 'TotalCharges']
# Categoric Columns: ['OnlineSecurity', 'StreamingMovies', 'PhoneService', 'StreamingTV', 'Contract', 'TechSupport', 'PaperlessBilling', 'InternetService', 'PaymentMethod', 'DeviceProtection', 'gender', 'MultipleLines', 'SeniorCitizen', 'OnlineBackup', 'Partner', 'Churn', 'Dependents']
# Cardinal Columns: ['customerID']

# %% [markdown]
# ## Check Outliers One by One

# %%
from feature_utils import check_outliers

# %%
check_outliers(df, columns=numeric_cols, plot=1, q1_value=0.02, q3_value=0.98)
# Out:
# 2023-03-27 06:36:14,125 - logging_utils - DEBUG - check_outliers executing...
# 2023-03-27 06:36:14,382 - logging_utils - INFO - Dataframe Columns Outliers State:
# 2023-03-27 06:36:14,385 - logging_utils - INFO - tenure --> False
# 2023-03-27 06:36:14,388 - logging_utils - INFO - MonthlyCharges --> False
# 2023-03-27 06:36:14,392 - logging_utils - INFO - TotalCharges --> False

# %% [markdown]
# There is no outliers one by one.

# %% [markdown]
# ## Save Dataframe

# %%
df.to_csv('datasets/telco-nonoutliers.csv', index=False)

# %% [markdown]
# Continue with **eda jupyter file**.
